# %% [markdown]
# # rag-bench quickstart\nRun from a notebook.

# %%
from rag_bench.eval.dataset_loader import load_texts_as_documents
from rag_bench.pipelines.naive_rag import build_chain
docs = load_texts_as_documents(['examples/data/sample.txt'])
chain = build_chain(docs)
chain.invoke('What is LangChain?')
